# %%
from caispp import ImageDataset, ImageClassifier, Path

# %%
path = Path('example_dataset/')
dataset = ImageDataset(path, show_distribution=True)
# Out:
# Dataset distribution:

# %%
classifier = ImageClassifier(dataset)

# %%
classifier.train(epochs=10)
# Out:
# Train on 91 samples, validate on 3 samples
# Epoch 1/10
# 91/91 [==============================] - 17s 182ms/sample - loss: 1.1342 - acc: 0.5055 - val_loss: 1.1524 - val_acc: 0.6667
# Epoch 2/10
# 91/91 [==============================] - 12s 127ms/sample - loss: 0.7081 - acc: 0.7253 - val_loss: 0.7545 - val_acc: 0.6667
# Epoch 3/10
# 91/91 [==============================] - 11s 124ms/sample - loss: 0.5436 - acc: 0.8022 - val_loss: 0.4989 - val_acc: 0.6667
# Epoch 4/10
# 91/91 [==============================] - 11s 126ms/sample - loss: 0.4182 - acc: 0.8681 - val_loss: 0.3395 - val_acc: 1.0000
# Epoch 5/10
# 91/91 [==============================] - 13s 146ms/sample - loss: 0.3661 - acc: 0.8681 - val_loss: 0.2603 - val_acc: 1.0000
# Epoch 6/10
# 91/91 [==============================] - 13s 139ms/sample - loss: 0.2709 - acc: 0.9341 - val_loss: 0.2599 - val_acc: 1.0000
# Epoch 7/10
# 91/91 [==============================] - 13s 144ms/sample - loss: 0.1810 - acc: 0.9780 - val_loss: 0.4992 - val_acc: 0.6667
# Epoch 8/10
# 91/91 [==============================] - 13s 139ms/sample - loss: 0.1932 - acc: 0.9560 - val_loss: 0.2732 - val_acc: 0.6667
# Epoch 9/10
# 91/91 [==============================] - 13s 139ms/sample - loss: 0.1560 - acc: 0.9670 - val_loss: 0.1796 - val_acc: 1.0000
# Epoch 10/10
# 91/91 [==============================] - 13s 139ms/sample - loss: 0.1897 - acc: 0.9451 - val_loss: 0.3201 - val_acc: 0.6667

# %%
classifier.show_history('loss')

# %%
classifier.test(show_distribution=True)
# Out:
# Accuracy:  0.933 , f1-score:  0.935
