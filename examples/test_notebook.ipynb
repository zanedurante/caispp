# %%
from caispp import ImageDataset, ImageClassifier 
from pathlib import Path

# %%
path = Path('example_dataset/')
dataset = ImageDataset(path, show_distribution=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-2e69a842470b> in <module>
#       1 path = Path('example_dataset/')
# ----> 2 dataset = ImageDataset(path, show_distribution=True)
#
# /mnt/c/Users/zaned/linux/CAIS/caispp.py in __init__(self, path, show_distribution, ignore)
#     244
#     245         # Returns dict where flags[file] = True if the optional file exists
# --> 246         self.flags = self.__check_files(reqs, opts)
#     247
#     248         self.train_data = self.__get_data('train')
#
# /mnt/c/Users/zaned/linux/CAIS/caispp.py in __check_files(self, reqs, opts)
#     289             if self.path / PosixPath(req) not in files:
#     290                 raise FileNotFoundError(
# --> 291                     errno.ENOENT, os.strerror(errno.ENOENT), req)
#     292
#     293         # Create flag dictionary (flags[filename] is True when it exists)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train/'

# %%
classifier = ImageClassifier(dataset)

# %%
classifier.train(epochs=10) # TODO: find way to ignore the warning about Use tf.where in 2.0
# Out:
# Train on 91 samples, validate on 3 samples
# Epoch 1/10
# 91/91 [==============================] - 15s 161ms/sample - loss: 0.8593 - acc: 0.5824 - val_loss: 0.5314 - val_acc: 1.0000
# Epoch 2/10
# 91/91 [==============================] - 9s 95ms/sample - loss: 0.6983 - acc: 0.7473 - val_loss: 0.3341 - val_acc: 1.0000
# Epoch 3/10
# 91/91 [==============================] - 9s 95ms/sample - loss: 0.5265 - acc: 0.8132 - val_loss: 0.3234 - val_acc: 1.0000
# Epoch 4/10
# 91/91 [==============================] - 9s 103ms/sample - loss: 0.3652 - acc: 0.9231 - val_loss: 0.1654 - val_acc: 1.0000
# Epoch 5/10
# 91/91 [==============================] - 9s 100ms/sample - loss: 0.4323 - acc: 0.8462 - val_loss: 0.1587 - val_acc: 1.0000
# Epoch 6/10
# 91/91 [==============================] - 9s 103ms/sample - loss: 0.3007 - acc: 0.9121 - val_loss: 0.1056 - val_acc: 1.0000
# Epoch 7/10
# 91/91 [==============================] - 9s 104ms/sample - loss: 0.2173 - acc: 0.9780 - val_loss: 0.1520 - val_acc: 1.0000
# Epoch 8/10
# 91/91 [==============================] - 9s 98ms/sample - loss: 0.1778 - acc: 0.9670 - val_loss: 0.0708 - val_acc: 1.0000
# Epoch 9/10
# 91/91 [==============================] - 9s 100ms/sample - loss: 0.1790 - acc: 0.9890 - val_loss: 0.0707 - val_acc: 1.0000
# Epoch 10/10
# 91/91 [==============================] - 11s 123ms/sample - loss: 0.1914 - acc: 0.9451 - val_loss: 0.0560 - val_acc: 1.0000

# %%
classifier.show_history()

# %%
classifier.test(show_distribution=True)
# Out:
# Accuracy:  0.867 , f1-score:  0.867
